# %%
# Libraries for processing

import numpy as np
import pandas as pd
import datetime as dt
import quandl
import matplotlib.pyplot as plt
import seaborn as sns
import traces

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
# ease of display
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Import External Excel Data:

# %%
# Make list of labels of all Excel files to be read and concatenated
# Only years from 2010 through end of 2015 are being considered.
# Timeline of Quantitative Easing policy.

file_list_treasuries = []

for i in range(2010,2015):
    for j in range(1,5):
        file_list_treasuries.append(f'tsy_data_{i}_q{j}.xls')
    
file_list_treasuries
# Out:
# ['tsy_data_2010_q1.xls',
#  'tsy_data_2010_q2.xls',
#  'tsy_data_2010_q3.xls',
#  'tsy_data_2010_q4.xls',
#  'tsy_data_2011_q1.xls',
#  'tsy_data_2011_q2.xls',
#  'tsy_data_2011_q3.xls',
#  'tsy_data_2011_q4.xls',
#  'tsy_data_2012_q1.xls',
#  'tsy_data_2012_q2.xls',
#  'tsy_data_2012_q3.xls',
#  'tsy_data_2012_q4.xls',
#  'tsy_data_2013_q1.xls',
#  'tsy_data_2013_q2.xls',
#  'tsy_data_2013_q3.xls',
#  'tsy_data_2013_q4.xls',
#  'tsy_data_2014_q1.xls',
#  'tsy_data_2014_q2.xls',
#  'tsy_data_2014_q3.xls',
#  'tsy_data_2014_q4.xls']

# %%
# First 2 quarters of 2010 are not available.
file_list_treasuries = file_list_treasuries[2:]

# %%
# Concatenate primary DataFrame from Excel files.
df = pd.concat([pd.read_excel(f'../data/Treasuries/{file}') for file in file_list_treasuries])

# %%
df.head()
# Out:
#    U.S. TREASURY SECURITIES DATA           Unnamed: 1            Unnamed: 2  \
# 0  JULY 22 TO SEPTEMBER 30, 2010                  NaN                   NaN
# 1                            NaN                  NaN                   NaN
# 2                     Trade date      Settlement date  Transaction category
# 3            2010-08-17 00:00:00  2010-08-18 00:00:00              Purchase
# 4            2010-08-17 00:00:00  2010-08-18 00:00:00              Purchase
#
#                         Unnamed: 3 Unnamed: 4            Unnamed: 5  \
# 0                              NaN        NaN                   NaN
# 1                              NaN        NaN                   NaN
# 2  Trade amount (in millions, USD)     Issuer  Security description
# 3                               25        TSY  TN 02.375 02/28/15
# 4                               50        TSY  TN 02.375 10/31/14
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                              CUSIP      Price
# 3  912828MR8                                     ...    104.773
# 4  912828LS7                                     ...    104.922
#
#                            Unnamed: 8  \
# 0                                 NaN
# 1                                 NaN
# 2  Accrued interest (in dollars, USD)
# 3                              275900
# 4                              354959
#
#                                     Unnamed: 9                     Unnamed: 10
# 0                                          NaN                             NaN
# 1                                          NaN                             NaN
# 2  Total amount transferred (in millions, USD)                    Counterparty
# 3                                      26.4693  Banc of America Securities LLC
# 4                                      52.8159  Banc of America Securities LLC

# %% [markdown]
# ## Pre-Processing:

# %%
# Apply column names
labels = list(df.iloc[2])
df.columns = labels

# %%
df.head()
# Out:
#                       Trade date      Settlement date  Transaction category  \
# 0  JULY 22 TO SEPTEMBER 30, 2010                  NaN                   NaN
# 1                            NaN                  NaN                   NaN
# 2                     Trade date      Settlement date  Transaction category
# 3            2010-08-17 00:00:00  2010-08-18 00:00:00              Purchase
# 4            2010-08-17 00:00:00  2010-08-18 00:00:00              Purchase
#
#    Trade amount (in millions, USD)  Issuer  Security description  \
# 0                              NaN     NaN                   NaN
# 1                              NaN     NaN                   NaN
# 2  Trade amount (in millions, USD)  Issuer  Security description
# 3                               25     TSY  TN 02.375 02/28/15
# 4                               50     TSY  TN 02.375 10/31/14
#
#                                                CUSIP    Price  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                              CUSIP    Price
# 3  912828MR8                                     ...  104.773
# 4  912828LS7                                     ...  104.922
#
#    Accrued interest (in dollars, USD)  \
# 0                                 NaN
# 1                                 NaN
# 2  Accrued interest (in dollars, USD)
# 3                              275900
# 4                              354959
#
#    Total amount transferred (in millions, USD)                    Counterparty
# 0                                          NaN                             NaN
# 1                                          NaN                             NaN
# 2  Total amount transferred (in millions, USD)                    Counterparty
# 3                                      26.4693  Banc of America Securities LLC
# 4                                      52.8159  Banc of America Securities LLC

# %%
# Check for nulls
df.isnull().sum()
# Out:
# Trade date                                     18
# Settlement date                                36
# Transaction category                           36
# Trade amount (in millions, USD)                36
# Issuer                                         36
# Security description                           36
# CUSIP                                          36
# Price                                          36
# Accrued interest (in dollars, USD)             36
# Total amount transferred (in millions, USD)    36
# Counterparty                                   36
# dtype: int64

# %%
# Too few nulls for data quality to be damaged by dropping.
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (80926, 11)

# %%
df.dtypes
# Out:
# Trade date                                     object
# Settlement date                                object
# Transaction category                           object
# Trade amount (in millions, USD)                object
# Issuer                                         object
# Security description                           object
# CUSIP                                          object
# Price                                          object
# Accrued interest (in dollars, USD)             object
# Total amount transferred (in millions, USD)    object
# Counterparty                                   object
# dtype: object

# %%
# Finding and removing white space in string categories.
# Finding and removing errors of label name being in cell were discovered as well.
# check for name mismatch . Removes other rows with offending columns as well

# Example:
# This is when the string 'Trade date' was found instead of an actual date value

df[df['Trade date'] == 'Trade date'].shape
# Out:
# (18, 11)

# %%
df = df[df['Trade date'] != 'Trade date'].copy()

# %%
# extra whitespace
df['Transaction category'].value_counts()
# Out:
# Purchase    71745
# Sale         7120
# Sale         2043
# Name: Transaction category, dtype: int64

# %%
# Many corporate names for effectively same entity
df['Counterparty'].value_counts()
# Out:
# Morgan Stanley & Co. LLC                                                   18259
# BNP Paribas Securities Corp.                                               12077
# Goldman, Sachs & Co.                                                        7585
# Barclays Capital Inc.                                                       6820
# Merrill Lynch, Pierce, Fenner & Smith Incorporated                          4154
# Citigroup Global Markets Inc.                                               3135
# Credit Suisse Securities (USA) LLC                                          2832
# Deutsche Bank Securities Inc.                                               2794
# RBS Securities Inc.                                                         2510
# Nomura Securities International, Inc.                                       2304
# BMO Capital Markets Corp.                                                   1793
# RBC Capital Markets, LLC                                                    1567
# HSBC Securities (USA) Inc.                                                  1554
# Mizuho Securities USA Inc.                                                  1464
# UBS Securities LLC                                                          1353
# J.P. Morgan Securities LLC                                                  1308
# Daiwa Capital Markets America Inc.                                          1281
# Cantor Fitzgerald & Co.                                                     1244
# SG Americas Securities, LLC                                                 1100
# J. P. Morgan Securities LLC                                                  993
# Jefferies & Company, Inc.                                                    981
# Bank of Nova Scotia, New York Agency                                         951
# Morgan Stanley & Co. Incorporated                                            760
# UBS Securities LLC.                                                          421
# Jefferies LLC                                                                346
# Cabrera Capital Markets, LLC                                                 163
# G.X. Clarke & Co.                                                            154
# Goldman, Sachs & Co.                                                         140
# Bank of Nova Scotia, New York Agency.                                        118
# MF Global Inc.                                                               113
# Banc of America Securities LLC                                                68
# Morgan Stanley & Co. Incorporated                                             57
# TD Securities (USA) LLC                                                       54
# Credit Suisse Securities (USA) LLC                                            54
# Citigroup Global Markets Inc.                                                 50
# Barclays Capital Inc.                                                         37
# Deutsche Bank Securities Inc.                                                 35
# J. P. Morgan Securities LLC                                                   35
# BNP Paribas Securities Corp.                                                  33
# Jefferies & Company, Inc.                                                     26
# RBS Securities Inc.                                                           25
# Loop Capital Markets LLC                                                      23
# HSBC Securities (USA) Inc.                                                    23
# UBS Securities LLC.                                                           23
# J. P. Morgan Securities Inc.                                                  22
# Nomura Securities International, Inc.                                         17
# Mischler Financial Group, Inc.                                                15
# Cantor Fitzgerald & Co.                                                       13
# Daiwa Capital Markets America Inc.                                            13
# RBC Capital Markets Corporation                                                8
# RBC Capital Markets Corporation                                                3
# Name: Counterparty, dtype: int64

# %%
# Change data types ot integers and floats

df['Trade amount (in millions, USD)'] = df['Trade amount (in millions, USD)'].astype(int)
df['Price'] = df['Price'].astype(float)
df['Accrued interest (in dollars, USD)'] = df['Accrued interest (in dollars, USD)'].astype(float)
df['Total amount transferred (in millions, USD)'] = df['Total amount transferred (in millions, USD)'].astype(float)

# %%
# remover for whitespace
def space_remover(string):
    return string.replace(' ','')

# %%
df['Transaction category'] = df['Transaction category'].map(space_remover)
df['Transaction category'].value_counts()
# Out:
# Purchase    71745
# Sale         9163
# Name: Transaction category, dtype: int64

# %%
df['Security description'] = df['Security description'].map(space_remover)

# %%
# Condense singular names of Counterparty business entity

def CounterPartyNamer(string):
    if 'Goldman' in string:
        string = 'Goldman, Sachs & Co.'
        return string
    elif 'J.' in string:
        string = 'J.P. Morgan Securities LLC'
        return string
    elif 'Stanley' in string:
        string = 'Morgan Stanley & Co. LLC'
        return string
    elif 'RBC' in string:
        string = 'RBC Capital Markets, LLC'
        return string
    elif 'Barclay' in string:
        string = 'Barclays Capital Inc.'
        return string
    elif 'Jeffer' in string:
        string = 'Jefferies & Company, Inc.'
        return string
    elif 'Cantor' in string:
        string = 'Cantor Fitzgerald & Co.'
        return string
    elif 'Nomura' in string:
        string = 'Nomura Securities International, Inc.'
        return string
    elif 'RBS' in string:
        string = 'RBS Securities Inc.'
        return string
    elif 'Daiwa' in string:
        string = 'Daiwa Capital Markets America Inc.'
        return string
    elif 'HSBC' in string:
        string = 'HSBC Securities (USA) Inc.'
        return string
    elif 'Citigroup' in string:
        string = 'Citigroup Global Markets Inc.'
        return string
    elif 'BNP' in string:
        string = 'BNP Paribas Securities Corp.'
        return string
    elif 'UBS' in string:
        string = 'UBS Securities LLC'
        return string
    elif 'BMO' in string:
        string = 'BMO Capital Markets Corp.'
        return string
    elif 'Societe' in string:
        string = 'SG Americas Securities, LLC'
        return string
    elif 'Suisse' in string or 'SUISSE' in string:
        string = 'Credit Suisse Securities (USA) LLC'
        return string
    elif 'Deutsche' in string:
        string = 'Deutsche Bank Securities Inc.'
        return string
    elif 'Scotia' in string:
        string = 'Bank of Nova Scotia, New York Agency'
        return string
    elif 'Mizuho' in string:
        string = 'Mizuho Securities USA Inc.'
        return string
    elif 'TD' in string:
        string = 'TD Securities (USA) LLC'
        return string
    else:
        return string

# %%
# Counterparty names have now been standardized

df['Counterparty'] = df['Counterparty'].map(CounterPartyNamer)
df['Counterparty'].value_counts()
# Out:
# Morgan Stanley & Co. LLC                              19076
# BNP Paribas Securities Corp.                          12110
# Goldman, Sachs & Co.                                   7725
# Barclays Capital Inc.                                  6857
# Merrill Lynch, Pierce, Fenner & Smith Incorporated     4154
# Citigroup Global Markets Inc.                          3185
# Credit Suisse Securities (USA) LLC                     2886
# Deutsche Bank Securities Inc.                          2829
# RBS Securities Inc.                                    2535
# J.P. Morgan Securities LLC                             2358
# Nomura Securities International, Inc.                  2321
# UBS Securities LLC                                     1797
# BMO Capital Markets Corp.                              1793
# RBC Capital Markets, LLC                               1578
# HSBC Securities (USA) Inc.                             1577
# Mizuho Securities USA Inc.                             1464
# Jefferies & Company, Inc.                              1353
# Daiwa Capital Markets America Inc.                     1294
# Cantor Fitzgerald & Co.                                1257
# SG Americas Securities, LLC                            1100
# Bank of Nova Scotia, New York Agency                   1069
# Cabrera Capital Markets, LLC                            163
# G.X. Clarke & Co.                                       154
# MF Global Inc.                                          113
# Banc of America Securities LLC                           68
# TD Securities (USA) LLC                                  54
# Loop Capital Markets LLC                                 23
# Mischler Financial Group, Inc.                           15
# Name: Counterparty, dtype: int64

# %% [markdown]
# ## Feature Engineerging From Security Description

# %%
# Functions for partitioning Interest rate, type, and maturity date from Security Description.

def TermFinder(string):
    return string[-8:]

def CouponFinder(string):
    return string[-14:-8]

def SecType(string):
    return string[:2]

# %%
df['Type'] = df['Security description'].map(SecType)
df['Type'].value_counts()
# Out:
# TN    40900
# TB    36409
# II     3599
# Name: Type, dtype: int64

# %%
df['Coupon'] = df['Security description'].map(CouponFinder)
df['Coupon']
# Out:
# 3      02.375
# 4      02.375
# 5      02.375
# 6      02.625
# 7      02.375
#         ...
# 466    03.000
# 467    03.125
# 468    02.750
# 469    04.500
# 470    03.875
# Name: Coupon, Length: 80908, dtype: object

# %%
# additional extra character remover from string.

def BFinder(string):
    if 'B' in string:
        string = '0'
        return string
    else:
        return string

# %%
df['Coupon'].value_counts()
# Out:
# 04.375    6479
# 03.125    5481
# 04.250    3920
# 02.750    3735
# 04.500    3527
#           ...
# 05.375      93
# 09.875      91
# 04.875      57
# 05.125      41
# 09.250      34
# Name: Coupon, Length: 68, dtype: int64

# %%
df['Term'] = df['Security description'].map(TermFinder)
df['Term']
# Out:
# 3      02/28/15
# 4      10/31/14
# 5      08/31/14
# 6      12/31/14
# 7      09/30/14
#          ...
# 466    05/15/42
# 467    02/15/43
# 468    08/15/42
# 469    02/15/36
# 470    08/15/40
# Name: Term, Length: 80908, dtype: object

# %%
# Standardizing correct names for type of Treasury
type_dict = {'TN':'T-Note','TB':'T-Bill','B1':'Bond','II':'Inf_Indexed'}

# %%
df['Type'] = df['Type'].map(type_dict)
df['Type'].value_counts()
# Out:
# T-Note         40900
# T-Bill         36409
# Inf_Indexed     3599
# Name: Type, dtype: int64

# %%
df['Coupon'] = df['Coupon'].astype(float)

# %%
df['Term'] = pd.to_datetime(df['Term'])
df['Trade date'] = pd.to_datetime(df['Trade date'])
df['Settlement date'] = pd.to_datetime(df['Settlement date'])

# %%
# def TermFinder(string):
#     return string[-10:]

# def CouponFinder(string):
#     return string[-15:-8]

# def SecType(string):
#     return string[:3]

# %%
# def DateFixer(string):
#     if ' ' in string:
#         string = string.strip()
#         string = string[-8:]
#         return string
#     else:
#         return string

# %%
df.dtypes
# Out:
# Trade date                                     datetime64[ns]
# Settlement date                                datetime64[ns]
# Transaction category                                   object
# Trade amount (in millions, USD)                         int64
# Issuer                                                 object
# Security description                                   object
# CUSIP                                                  object
# Price                                                 float64
# Accrued interest (in dollars, USD)                    float64
# Total amount transferred (in millions, USD)           float64
# Counterparty                                           object
# Type                                                   object
# Coupon                                                float64
# Term                                           datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#   Trade date Settlement date Transaction category  \
# 3 2010-08-17      2010-08-18             Purchase
# 4 2010-08-17      2010-08-18             Purchase
# 5 2010-08-17      2010-08-18             Purchase
# 6 2010-08-17      2010-08-18             Purchase
# 7 2010-08-17      2010-08-18             Purchase
#
#    Trade amount (in millions, USD) Issuer Security description  \
# 3                               25    TSY     TN02.37502/28/15
# 4                               50    TSY     TN02.37510/31/14
# 5                               10    TSY     TN02.37508/31/14
# 6                               50    TSY     TN02.62512/31/14
# 7                              100    TSY     TN02.37509/30/14
#
#                                                CUSIP       Price  \
# 3  912828MR8                                     ...  104.773438
# 4  912828LS7                                     ...  104.921875
# 5  912828LK4                                     ...  104.968750
# 6  912828ME7                                     ...  105.937500
# 7  912828LQ1                                     ...  104.945312
#
#    Accrued interest (in dollars, USD)  \
# 3                           275900.14
# 4                           354959.24
# 5                           110360.05
# 6                           174762.23
# 7                           908469.94
#
#    Total amount transferred (in millions, USD)  \
# 3                                    26.469260
# 4                                    52.815897
# 5                                    10.607235
# 6                                    53.143512
# 7                                   105.853782
#
#                      Counterparty    Type  Coupon       Term
# 3  Banc of America Securities LLC  T-Note   2.375 2015-02-28
# 4  Banc of America Securities LLC  T-Note   2.375 2014-10-31
# 5  Banc of America Securities LLC  T-Note   2.375 2014-08-31
# 6  Banc of America Securities LLC  T-Note   2.625 2014-12-31
# 7           Barclays Capital Inc.  T-Note   2.375 2014-09-30

# %% [markdown]
# ## Quandl: Retrieve Time Indexed Yield Curve information

# %%
quandl.ApiConfig.api_key = '-szaxxRjfjXjAhBgEzYR'

# %%
# API call for U.S. Treasury Yield Curve data.
yc = quandl.get("USTREASURY/YIELD", authtoken="-szaxxRjfjXjAhBgEzYR")

# %%
yc.shape
# Out:
# (7738, 12)

# %%
yc = yc.loc['2010':'2014'].copy()

# %%
yc.shape
# Out:
# (1251, 12)

# %%
df['Trade date']
# Out:
# 3     2010-08-17
# 4     2010-08-17
# 5     2010-08-17
# 6     2010-08-17
# 7     2010-08-17
#          ...
# 466   2014-10-27
# 467   2014-10-27
# 468   2014-10-27
# 469   2014-10-27
# 470   2014-10-27
# Name: Trade date, Length: 80908, dtype: datetime64[ns]

# %%
# https://stackoverflow.com/questions/39019591/duplicated-rows-when-merging-dataframes-in-python
# Join yield curve data on Treasury Transaction data by date.
# Many duplicates as transactions are intraday and Yield Curve interest rates are daily.

yc['Trade date'] = yc.index
df = pd.merge(df,yc.drop_duplicates(),on=['Trade date'])

# %%
df.head()
# Out:
#   Trade date Settlement date Transaction category  \
# 0 2010-08-17      2010-08-18             Purchase
# 1 2010-08-17      2010-08-18             Purchase
# 2 2010-08-17      2010-08-18             Purchase
# 3 2010-08-17      2010-08-18             Purchase
# 4 2010-08-17      2010-08-18             Purchase
#
#    Trade amount (in millions, USD) Issuer Security description  \
# 0                               25    TSY     TN02.37502/28/15
# 1                               50    TSY     TN02.37510/31/14
# 2                               10    TSY     TN02.37508/31/14
# 3                               50    TSY     TN02.62512/31/14
# 4                              100    TSY     TN02.37509/30/14
#
#                                                CUSIP       Price  \
# 0  912828MR8                                     ...  104.773438
# 1  912828LS7                                     ...  104.921875
# 2  912828LK4                                     ...  104.968750
# 3  912828ME7                                     ...  105.937500
# 4  912828LQ1                                     ...  104.945312
#
#    Accrued interest (in dollars, USD)  \
# 0                           275900.14
# 1                           354959.24
# 2                           110360.05
# 3                           174762.23
# 4                           908469.94
#
#    Total amount transferred (in millions, USD)  \
# 0                                    26.469260
# 1                                    52.815897
# 2                                    10.607235
# 3                                    53.143512
# 4                                   105.853782
#
#                      Counterparty    Type  Coupon       Term  1 MO  2 MO  \
# 0  Banc of America Securities LLC  T-Note   2.375 2015-02-28  0.16   NaN
# 1  Banc of America Securities LLC  T-Note   2.375 2014-10-31  0.16   NaN
# 2  Banc of America Securities LLC  T-Note   2.375 2014-08-31  0.16   NaN
# 3  Banc of America Securities LLC  T-Note   2.625 2014-12-31  0.16   NaN
# 4           Barclays Capital Inc.  T-Note   2.375 2014-09-30  0.16   NaN
#
#    3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  20 YR  30 YR
# 0  0.17  0.19  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 1  0.17  0.19  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 2  0.17  0.19  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 3  0.17  0.19  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 4  0.17  0.19  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77

# %%
# https://stackoverflow.com/questions/40923820/pandas-timedelta-in-months
# Feature Engineering Remaining time to maturity when treasury was purchased

df['Time to Maturity (Years)'] = (df['Term'] - df['Trade date']) / np.timedelta64(1,'Y')
df['Time to Maturity (Months)'] = (df['Term'] - df['Trade date']) / np.timedelta64(1,'M')

# %%
# Renaming type of Treasury.

def BondDef(string):
    if 'Bill' in string:
        string = 'T-Bond'
        return string
    elif string == 'Bond':
        string = 'T-Bill'
        return string
    else:
        return string

# %%
df['Type'] = df['Type'].map(BondDef)

# %% [markdown]
# ### Export file for use in EDA

# %%
df.reset_index(inplace=True)

# %%
df.shape
# Out:
# (80908, 29)

# %%
# df.to_csv('../data/csv_exports/edaFINAL.csv')

# %% [markdown]
# ### Encoding and Processing for Models:

# %%
# First is purchase category
df = pd.get_dummies(df,columns=['Transaction category'],drop_first=True)

# %%
# First is inflation indexed instrument
df = pd.get_dummies(df,columns=['Type'],drop_first=True)

# %%
df.dtypes
# Out:
# index                                                   int64
# Trade date                                     datetime64[ns]
# Settlement date                                datetime64[ns]
# Trade amount (in millions, USD)                         int64
# Issuer                                                 object
# Security description                                   object
# CUSIP                                                  object
# Price                                                 float64
# Accrued interest (in dollars, USD)                    float64
# Total amount transferred (in millions, USD)           float64
# Counterparty                                           object
# Coupon                                                float64
# Term                                           datetime64[ns]
# 1 MO                                                  float64
# 2 MO                                                  float64
# 3 MO                                                  float64
# 6 MO                                                  float64
# 1 YR                                                  float64
# 2 YR                                                  float64
# 3 YR                                                  float64
# 5 YR                                                  float64
# 7 YR                                                  float64
# 10 YR                                                 float64
# 20 YR                                                 float64
# 30 YR                                                 float64
# Time to Maturity (Years)                              float64
# Time to Maturity (Months)                             float64
# Transaction category_Sale                               uint8
# Type_T-Bond                                             uint8
# Type_T-Note                                             uint8
# dtype: object

# %%
df.head()
# Out:
#    index Trade date Settlement date  Trade amount (in millions, USD) Issuer  \
# 0      0 2010-08-17      2010-08-18                               25    TSY
# 1      1 2010-08-17      2010-08-18                               50    TSY
# 2      2 2010-08-17      2010-08-18                               10    TSY
# 3      3 2010-08-17      2010-08-18                               50    TSY
# 4      4 2010-08-17      2010-08-18                              100    TSY
#
#   Security description                                              CUSIP  \
# 0     TN02.37502/28/15  912828MR8                                     ...
# 1     TN02.37510/31/14  912828LS7                                     ...
# 2     TN02.37508/31/14  912828LK4                                     ...
# 3     TN02.62512/31/14  912828ME7                                     ...
# 4     TN02.37509/30/14  912828LQ1                                     ...
#
#         Price  Accrued interest (in dollars, USD)  \
# 0  104.773438                           275900.14
# 1  104.921875                           354959.24
# 2  104.968750                           110360.05
# 3  105.937500                           174762.23
# 4  104.945312                           908469.94
#
#    Total amount transferred (in millions, USD)  \
# 0                                    26.469260
# 1                                    52.815897
# 2                                    10.607235
# 3                                    53.143512
# 4                                   105.853782
#
#                      Counterparty  Coupon       Term  1 MO  2 MO  3 MO  6 MO  \
# 0  Banc of America Securities LLC   2.375 2015-02-28  0.16   NaN  0.17  0.19
# 1  Banc of America Securities LLC   2.375 2014-10-31  0.16   NaN  0.17  0.19
# 2  Banc of America Securities LLC   2.375 2014-08-31  0.16   NaN  0.17  0.19
# 3  Banc of America Securities LLC   2.625 2014-12-31  0.16   NaN  0.17  0.19
# 4           Barclays Capital Inc.   2.375 2014-09-30  0.16   NaN  0.17  0.19
#
#    1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  20 YR  30 YR  \
# 0  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 1  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 2  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 3  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 4  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
#
#    Time to Maturity (Years)  Time to Maturity (Months)  \
# 0                  4.533974                  54.407688
# 1                  4.205425                  50.465102
# 2                  4.038413                  48.460954
# 3                  4.372437                  52.469250
# 4                  4.120550                  49.446601
#
#    Transaction category_Sale  Type_T-Bond  Type_T-Note
# 0                          0            0            1
# 1                          0            0            1
# 2                          0            0            1
# 3                          0            0            1
# 4                          0            0            1

# %%
# 2 Month rate feature will be dropped as it is entirely null.
df.isnull().sum()
# Out:
# index                                              0
# Trade date                                         0
# Settlement date                                    0
# Trade amount (in millions, USD)                    0
# Issuer                                             0
# Security description                               0
# CUSIP                                              0
# Price                                              0
# Accrued interest (in dollars, USD)                 0
# Total amount transferred (in millions, USD)        0
# Counterparty                                       0
# Coupon                                             0
# Term                                               0
# 1 MO                                               0
# 2 MO                                           80908
# 3 MO                                               0
# 6 MO                                               0
# 1 YR                                               0
# 2 YR                                               0
# 3 YR                                               0
# 5 YR                                               0
# 7 YR                                               0
# 10 YR                                              0
# 20 YR                                              0
# 30 YR                                              0
# Time to Maturity (Years)                           0
# Time to Maturity (Months)                          0
# Transaction category_Sale                          0
# Type_T-Bond                                        0
# Type_T-Note                                        0
# dtype: int64

# %%
# Droping other features that are not relevant for modeling.
df.drop(columns=['CUSIP','Security description','index','Issuer','2 MO'],inplace=True)

# %%
df.dtypes
# Out:
# Trade date                                     datetime64[ns]
# Settlement date                                datetime64[ns]
# Trade amount (in millions, USD)                         int64
# Price                                                 float64
# Accrued interest (in dollars, USD)                    float64
# Total amount transferred (in millions, USD)           float64
# Counterparty                                           object
# Coupon                                                float64
# Term                                           datetime64[ns]
# 1 MO                                                  float64
# 3 MO                                                  float64
# 6 MO                                                  float64
# 1 YR                                                  float64
# 2 YR                                                  float64
# 3 YR                                                  float64
# 5 YR                                                  float64
# 7 YR                                                  float64
# 10 YR                                                 float64
# 20 YR                                                 float64
# 30 YR                                                 float64
# Time to Maturity (Years)                              float64
# Time to Maturity (Months)                             float64
# Transaction category_Sale                               uint8
# Type_T-Bond                                             uint8
# Type_T-Note                                             uint8
# dtype: object

# %%
# Separate data for modeling encoded counterparty
# Two DataFrames: One with encoded counterparties, another without.

counterparty_df = pd.get_dummies(df,columns=['Counterparty'],drop_first=True)

# %%
# condense data to each day with aggregates for option
# Aggregating useful measures on individual day
# https://stackoverflow.com/questions/14529838/apply-multiple-functions-to-multiple-groupby-columns
# This DataFrame was ultimately not used

dailydata = df.groupby('Trade date').agg({'Trade amount (in millions, USD)':['sum','mean'],
                                          'Price':'mean',
                                          'Counterparty':'count',
                                          'Coupon':'mean',
                                          'Transaction category_Sale':'count',
                                          'Time to Maturity (Years)':'mean',
                                          'Time to Maturity (Months)':'mean',
                                          'Total amount transferred (in millions, USD)':['sum','mean']
                                         })

# %%
daily_df = pd.merge(dailydata,yc.drop_duplicates(),on=['Trade date'])
# Out:
# /Users/ash/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
daily_df.head()
# Out:
#   Trade date  (Trade amount (in millions, USD), sum)  \
# 0 2010-08-17                                    2551
# 1 2010-08-19                                    3609
# 2 2010-08-24                                    1350
# 3 2010-08-26                                    1415
# 4 2010-08-30                                     360
#
#    (Trade amount (in millions, USD), mean)  (Price, mean)  \
# 0                                33.129870     105.687043
# 1                                73.653061     107.213249
# 2                                50.000000     101.663194
# 3                                37.236842     141.454770
# 4                                21.176471     113.124081
#
#    (Counterparty, count)  (Coupon, mean)  (Transaction category_Sale, count)  \
# 0                     77        2.564935                                  77
# 1                     49        3.071429                                  49
# 2                     27        1.259259                                  27
# 3                     38        6.963816                                  38
# 4                     17        2.139706                                  17
#
#    (Time to Maturity (Years), mean)  (Time to Maturity (Months), mean)  \
# 0                          4.388687                          52.664246
# 1                          6.550247                          78.602963
# 2                          2.813554                          33.762652
# 3                         15.814295                         189.771540
# 4                         11.773161                         141.277934
#
#    (Total amount transferred (in millions, USD), sum)  \
# 0                                        2711.817050
# 1                                        3903.637809
# 2                                        1373.310600
# 3                                        2085.439888
# 4                                         421.420783
#
#    (Total amount transferred (in millions, USD), mean)  1 MO  2 MO  3 MO  \
# 0                                          35.218403    0.16   NaN  0.17
# 1                                          79.666078    0.16   NaN  0.16
# 2                                          50.863356    0.17   NaN  0.16
# 3                                          54.879997    0.17   NaN  0.16
# 4                                          24.789458    0.16   NaN  0.14
#
#    6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  20 YR  30 YR
# 0  0.19  0.26  0.52  0.78  1.44  2.06   2.64   3.47   3.77
# 1  0.19  0.25  0.49  0.74  1.41  2.02   2.58   3.37   3.66
# 2  0.20  0.27  0.50  0.72  1.36  1.95   2.50   3.28   3.57
# 3  0.19  0.25  0.51  0.77  1.38  1.97   2.50   3.25   3.53
# 4  0.19  0.26  0.50  0.75  1.39  1.98   2.54   3.30   3.60

# %%
daily_df.shape
# Out:
# (822, 23)

# %%
df.drop(columns='Counterparty',inplace=True)

# %% [markdown]
# ### Interpolating Evenly Spaced Time Intervals that Match Row Number: Traces

# %%
df.index = df['Trade date']

# %%
# Iniitalize traces object for resampling uneven time index
# traces was imported above.

ts = traces.TimeSeries(df['Trade date'])

# %%
# https://stackoverflow.com/questions/25234941/python-regularise-irregular-time-series-with-linear-interpolation/39730384
# Trail and error was used to find number of minutes that keep same number of rows

ts1 = ts.sample(
    sampling_period=dt.timedelta(minutes=27.2845),
    start=dt.datetime(2010,8,17),
    end=dt.datetime(2014,10,28),
)

# %%
# rows are now evenly spaced.
pd.DataFrame(ts1).head()
# Out:
#                         0                                                  1
# 0 2010-08-17 00:00:00.000  Trade date
# 2010-08-17   2010-08-17
# 2010-08-17 ...
# 1 2010-08-17 00:27:17.070  Trade date
# 2010-08-17   2010-08-17
# 2010-08-17 ...
# 2 2010-08-17 00:54:34.140  Trade date
# 2010-08-17   2010-08-17
# 2010-08-17 ...
# 3 2010-08-17 01:21:51.210  Trade date
# 2010-08-17   2010-08-17
# 2010-08-17 ...
# 4 2010-08-17 01:49:08.280  Trade date
# 2010-08-17   2010-08-17
# 2010-08-17 ...

# %%
# Make evenly spaceed time series rows as index.
eventime = pd.DataFrame(ts1)
df.index = eventime[eventime.columns[0]]

# %%
df.head()
# Out:
#                         Trade date Settlement date  \
# 0
# 2010-08-17 00:00:00.000 2010-08-17      2010-08-18
# 2010-08-17 00:27:17.070 2010-08-17      2010-08-18
# 2010-08-17 00:54:34.140 2010-08-17      2010-08-18
# 2010-08-17 01:21:51.210 2010-08-17      2010-08-18
# 2010-08-17 01:49:08.280 2010-08-17      2010-08-18
#
#                          Trade amount (in millions, USD)       Price  \
# 0
# 2010-08-17 00:00:00.000                               25  104.773438
# 2010-08-17 00:27:17.070                               50  104.921875
# 2010-08-17 00:54:34.140                               10  104.968750
# 2010-08-17 01:21:51.210                               50  105.937500
# 2010-08-17 01:49:08.280                              100  104.945312
#
#                          Accrued interest (in dollars, USD)  \
# 0
# 2010-08-17 00:00:00.000                           275900.14
# 2010-08-17 00:27:17.070                           354959.24
# 2010-08-17 00:54:34.140                           110360.05
# 2010-08-17 01:21:51.210                           174762.23
# 2010-08-17 01:49:08.280                           908469.94
#
#                          Total amount transferred (in millions, USD)  Coupon  \
# 0
# 2010-08-17 00:00:00.000                                    26.469260   2.375
# 2010-08-17 00:27:17.070                                    52.815897   2.375
# 2010-08-17 00:54:34.140                                    10.607235   2.375
# 2010-08-17 01:21:51.210                                    53.143512   2.625
# 2010-08-17 01:49:08.280                                   105.853782   2.375
#
#                               Term  1 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  \
# 0
# 2010-08-17 00:00:00.000 2015-02-28  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 00:27:17.070 2014-10-31  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 00:54:34.140 2014-08-31  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 01:21:51.210 2014-12-31  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 01:49:08.280 2014-09-30  0.16  0.17  0.19  0.26  0.52  0.78  1.44
#
#                          7 YR  10 YR  20 YR  30 YR  Time to Maturity (Years)  \
# 0
# 2010-08-17 00:00:00.000  2.06   2.64   3.47   3.77                  4.533974
# 2010-08-17 00:27:17.070  2.06   2.64   3.47   3.77                  4.205425
# 2010-08-17 00:54:34.140  2.06   2.64   3.47   3.77                  4.038413
# 2010-08-17 01:21:51.210  2.06   2.64   3.47   3.77                  4.372437
# 2010-08-17 01:49:08.280  2.06   2.64   3.47   3.77                  4.120550
#
#                          Time to Maturity (Months)  Transaction category_Sale  \
# 0
# 2010-08-17 00:00:00.000                  54.407688                          0
# 2010-08-17 00:27:17.070                  50.465102                          0
# 2010-08-17 00:54:34.140                  48.460954                          0
# 2010-08-17 01:21:51.210                  52.469250                          0
# 2010-08-17 01:49:08.280                  49.446601                          0
#
#                          Type_T-Bond  Type_T-Note
# 0
# 2010-08-17 00:00:00.000            0            1
# 2010-08-17 00:27:17.070            0            1
# 2010-08-17 00:54:34.140            0            1
# 2010-08-17 01:21:51.210            0            1
# 2010-08-17 01:49:08.280            0            1

# %%
df.shape
# Out:
# (80908, 24)

# %%
# Same index procedure for DataFrame with Encoded Counterparties
counterparty_df.index = eventime[eventime.columns[0]]

# %% [markdown]
# ## Final Exports for Modeling:

# %%
df.to_csv('../data/csv_exports/nocp_FINAL_modeling.csv')
counterparty_df.to_csv('../data/csv_exports/FINAL_modeling.csv')

# %%
# df = pd.read_csv('../data/csv_exports/nocp_FINAL_modeling.csv')
# counterparty_df = pd.read_csv('../data/csv_exports/FINAL_modeling.csv')

# %%
# verify results
df
# Out:
#                         Trade date Settlement date  \
# 0
# 2010-08-17 00:00:00.000 2010-08-17      2010-08-18
# 2010-08-17 00:27:17.070 2010-08-17      2010-08-18
# 2010-08-17 00:54:34.140 2010-08-17      2010-08-18
# 2010-08-17 01:21:51.210 2010-08-17      2010-08-18
# 2010-08-17 01:49:08.280 2010-08-17      2010-08-18
# ...                            ...             ...
# 2014-10-27 21:57:54.210 2014-10-27      2014-10-28
# 2014-10-27 22:25:11.280 2014-10-27      2014-10-28
# 2014-10-27 22:52:28.350 2014-10-27      2014-10-28
# 2014-10-27 23:19:45.420 2014-10-27      2014-10-28
# 2014-10-27 23:47:02.490 2014-10-27      2014-10-28
#
#                          Trade amount (in millions, USD)       Price  \
# 0
# 2010-08-17 00:00:00.000                               25  104.773438
# 2010-08-17 00:27:17.070                               50  104.921875
# 2010-08-17 00:54:34.140                               10  104.968750
# 2010-08-17 01:21:51.210                               50  105.937500
# 2010-08-17 01:49:08.280                              100  104.945312
# ...                                                  ...         ...
# 2014-10-27 21:57:54.210                               35   99.890625
# 2014-10-27 22:25:11.280                               25  101.953125
# 2014-10-27 22:52:28.350                               35   94.875000
# 2014-10-27 23:19:45.420                                5  127.593750
# 2014-10-27 23:47:02.490                               10  116.968750
#
#                          Accrued interest (in dollars, USD)  \
# 0
# 2010-08-17 00:00:00.000                           275900.14
# 2010-08-17 00:27:17.070                           354959.24
# 2010-08-17 00:54:34.140                           110360.05
# 2010-08-17 01:21:51.210                           174762.23
# 2010-08-17 01:49:08.280                           908469.94
# ...                                                     ...
# 2014-10-27 21:57:54.210                           473641.30
# 2014-10-27 22:25:11.280                           157099.18
# 2014-10-27 22:52:28.350                           193546.20
# 2014-10-27 23:19:45.420                            45244.57
# 2014-10-27 23:47:02.490                            77921.20
#
#                          Total amount transferred (in millions, USD)  Coupon  \
# 0
# 2010-08-17 00:00:00.000                                    26.469260   2.375
# 2010-08-17 00:27:17.070                                    52.815897   2.375
# 2010-08-17 00:54:34.140                                    10.607235   2.375
# 2010-08-17 01:21:51.210                                    53.143512   2.625
# 2010-08-17 01:49:08.280                                   105.853782   2.375
# ...                                                              ...     ...
# 2014-10-27 21:57:54.210                                    35.435360   3.000
# 2014-10-27 22:25:11.280                                    25.645380   3.125
# 2014-10-27 22:52:28.350                                    33.399796   2.750
# 2014-10-27 23:19:45.420                                     6.424932   4.500
# 2014-10-27 23:47:02.490                                    11.774796   3.875
#
#                               Term  1 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  \
# 0
# 2010-08-17 00:00:00.000 2015-02-28  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 00:27:17.070 2014-10-31  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 00:54:34.140 2014-08-31  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 01:21:51.210 2014-12-31  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# 2010-08-17 01:49:08.280 2014-09-30  0.16  0.17  0.19  0.26  0.52  0.78  1.44
# ...                            ...   ...   ...   ...   ...   ...   ...   ...
# 2014-10-27 21:57:54.210 2042-05-15  0.03  0.02  0.06  0.11  0.41  0.81  1.51
# 2014-10-27 22:25:11.280 2043-02-15  0.03  0.02  0.06  0.11  0.41  0.81  1.51
# 2014-10-27 22:52:28.350 2042-08-15  0.03  0.02  0.06  0.11  0.41  0.81  1.51
# 2014-10-27 23:19:45.420 2036-02-15  0.03  0.02  0.06  0.11  0.41  0.81  1.51
# 2014-10-27 23:47:02.490 2040-08-15  0.03  0.02  0.06  0.11  0.41  0.81  1.51
#
#                          7 YR  10 YR  20 YR  30 YR  Time to Maturity (Years)  \
# 0
# 2010-08-17 00:00:00.000  2.06   2.64   3.47   3.77                  4.533974
# 2010-08-17 00:27:17.070  2.06   2.64   3.47   3.77                  4.205425
# 2010-08-17 00:54:34.140  2.06   2.64   3.47   3.77                  4.038413
# 2010-08-17 01:21:51.210  2.06   2.64   3.47   3.77                  4.372437
# 2010-08-17 01:49:08.280  2.06   2.64   3.47   3.77                  4.120550
# ...                       ...    ...    ...    ...                       ...
# 2014-10-27 21:57:54.210  1.94   2.27   2.75   3.04                 27.548820
# 2014-10-27 22:25:11.280  1.94   2.27   2.75   3.04                 28.304483
# 2014-10-27 22:52:28.350  1.94   2.27   2.75   3.04                 27.800708
# 2014-10-27 23:19:45.420  1.94   2.27   2.75   3.04                 21.303654
# 2014-10-27 23:47:02.490  1.94   2.27   2.75   3.04                 25.802036
#
#                          Time to Maturity (Months)  Transaction category_Sale  \
# 0
# 2010-08-17 00:00:00.000                  54.407688                          0
# 2010-08-17 00:27:17.070                  50.465102                          0
# 2010-08-17 00:54:34.140                  48.460954                          0
# 2010-08-17 01:21:51.210                  52.469250                          0
# 2010-08-17 01:49:08.280                  49.446601                          0
# ...                                            ...                        ...
# 2014-10-27 21:57:54.210                 330.585844                          0
# 2014-10-27 22:25:11.280                 339.653792                          0
# 2014-10-27 22:52:28.350                 333.608493                          0
# 2014-10-27 23:19:45.420                 255.643853                          0
# 2014-10-27 23:47:02.490                 309.624428                          0
#
#                          Type_T-Bond  Type_T-Note
# 0
# 2010-08-17 00:00:00.000            0            1
# 2010-08-17 00:27:17.070            0            1
# 2010-08-17 00:54:34.140            0            1
# 2010-08-17 01:21:51.210            0            1
# 2010-08-17 01:49:08.280            0            1
# ...                              ...          ...
# 2014-10-27 21:57:54.210            1            0
# 2014-10-27 22:25:11.280            1            0
# 2014-10-27 22:52:28.350            1            0
# 2014-10-27 23:19:45.420            1            0
# 2014-10-27 23:47:02.490            1            0
#
# [80908 rows x 24 columns]
