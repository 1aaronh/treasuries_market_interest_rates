# %%
import quandl
import pandas as pd
import matplotlib.pyplot as plt

# %%
quandl.ApiConfig.api_key = '-szaxxRjfjXjAhBgEzYR'

# %%
quandl.get()

# %%
eod = pd.read_csv('../../../../../Downloads/EOD_metadata.csv')

# %%
eod.head()
# Out:
#    code                                               name  \
# 0     A  Agilent Technologies Inc. (A) Stock Prices, Di...
# 1    AA  Alcoa Corporation (AA) Stock Prices, Dividends...
# 2   AAA  LISTED FUND TRUST (AAA) Stock Prices, Dividend...
# 3  AAAP  Advanced Accelerator Applications S.A. (AAAP) ...
# 4  AAAU  Perth Mint Physical Gold ETF Shares (AAAU) Sto...
#
#                                          description         refreshed_at  \
# 0  <p><b>Ticker</b>: A</p> <p><b>Exchange</b>: NY...  2020-11-24 01:41:01
# 1  <p><b>Ticker</b>: AA</p> <p><b>Exchange</b>: N...  2020-11-24 01:41:17
# 2  <p><b>Ticker</b>: AAA</p> <p><b>Exchange</b>: ...  2020-11-24 01:41:45
# 3  <p><b>Ticker</b>: AAAP</p> <p><b>Exchange</b>:...  2018-04-08 09:22:56
# 4  <p><b>Ticker</b>: AAAU</p> <p><b>Exchange</b>:...  2020-11-24 01:41:45
#
#     from_date     to_date
# 0  1999-11-18  2020-11-23
# 1  2016-11-01  2020-11-23
# 2  2020-09-09  2020-11-23
# 3  2015-11-11  2018-02-09
# 4  2018-08-15  2020-11-23

# %%
eod.iloc[5200:5250]
# Out:
#             code                                               name  \
# 5200     FRC_P_E  FIRST REPUBLIC BANK Depositary Shs Repstg 1/40...
# 5201  FRC_P_E_CL  FIRST REPUBLIC BANK Depositary Shs Repstg 1/40...
# 5202     FRC_P_F  FIRST REPUBLIC BANK Depositary Shares Series F...
# 5203     FRC_P_G  FIRST REPUBLIC BANK Depositary Shares Series G...
# 5204     FRC_P_H  FIRST REPUBLIC BANK Depositary Shares Series H...
# 5205     FRC_P_I  FIRST REPUBLIC BANK Depositary Shares Series I...
# 5206     FRC_P_J  FIRST REPUBLIC BANK Depositary Shares Series J...
# 5207     FRC_P_K  FIRST REPUBLIC BANK Depositary Shares Series K...
# 5208         FRD  Friedman Industries Inc. (FRD) Stock Prices, D...
# 5209        FRED  Fred's Inc. (FRED) Stock Prices, Dividends and...
# 5210       FREDQ  Fred's Inc. (FREDQ) Stock Prices, Dividends an...
# 5211        FREE  Whole Earth Brands Inc. (FREE) Stock Prices, D...
# 5212        FREL  FIDELITY COV TRS (FREL) Stock Prices, Dividend...
# ...

# %%
eod['description'][0]
# Out:
# "<p><b>Ticker</b>: A</p> <p><b>Exchange</b>: NYSE</p> <p>Prices, dividends, splits for Agilent Technologies Inc. (A).  <p>Columns:</p> <p>Open, High, Low, Close, Volume are <b>unadjusted</b>.</p> <p>Dividend shows the <b>unadjusted</b> dividend on any ex-dividend date else 0.0.</p> <p>Split shows any split that occurred on a the given DATE else 1.0</p> <p>Adjusted values are adjusted for dividends and splits using the <a href='http://www.crsp.com/products/documentation/crsp-calculations'>CRSP methodology</a>.</p> <p>Updates of this dataset occur at 5pm ET.  Subsequent corrections from the exchange are applied at 9pm ET.</p> <p>Data is sourced from NASDAQ, NYSE and AMEX via <a href='http://www.quotemedia.com'>Quotemedia</a>.</p>  "

# %%
# quandl.get("ABG/Price")

# %%
quandl.get("EIA/PET_RWTC_D")
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# ...           ...
# 2020-11-10  41.18
# 2020-11-11  41.23
# 2020-11-12  40.90
# 2020-11-13  39.93
# 2020-11-16  41.14
#
# [8812 rows x 1 columns]

# %%
ycdf = quandl.get("USTREASURY/YIELD", authtoken="-szaxxRjfjXjAhBgEzYR")

# %%
ycdf.shape
# Out:
# (7730, 12)

# %%
ycdf.head(15)
# Out:
#             1 MO  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  \
# Date
# 1990-01-02   NaN   NaN  7.83  7.89  7.81  7.87  7.90  7.87  7.98   7.94
# 1990-01-03   NaN   NaN  7.89  7.94  7.85  7.94  7.96  7.92  8.04   7.99
# 1990-01-04   NaN   NaN  7.84  7.90  7.82  7.92  7.93  7.91  8.02   7.98
# 1990-01-05   NaN   NaN  7.79  7.85  7.79  7.90  7.94  7.92  8.03   7.99
# 1990-01-08   NaN   NaN  7.79  7.88  7.81  7.90  7.95  7.92  8.05   8.02
# 1990-01-09   NaN   NaN  7.80  7.82  7.78  7.91  7.94  7.92  8.05   8.02
# 1990-01-10   NaN   NaN  7.75  7.78  7.77  7.91  7.95  7.92  8.00   8.03
# 1990-01-11   NaN   NaN  7.80  7.80  7.77  7.91  7.95  7.94  8.01   8.04
# 1990-01-12   NaN   NaN  7.74  7.81  7.76  7.93  7.98  7.99  8.07   8.10
# 1990-01-16   NaN   NaN  7.89  7.99  7.92  8.10  8.13  8.11  8.18   8.20
# 1990-01-17   NaN   NaN  7.97  7.97  7.91  8.09  8.11  8.11  8.17   8.19
# 1990-01-18   NaN   NaN  8.04  8.08  8.05  8.25  8.28  8.27  8.31   8.32
# ...

# %%
ycdf['3 YR'].isnull().sum()
# Out:
# 0

# %%
dfyc = ycdf.loc['2010':'2020'].copy()

# %%
dfyc
# Out:
#             1 MO  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  \
# Date
# 2010-01-04  0.05   NaN  0.08  0.18  0.45  1.09  1.66  2.65  3.36   3.85
# 2010-01-05  0.03   NaN  0.07  0.17  0.41  1.01  1.57  2.56  3.28   3.77
# 2010-01-06  0.03   NaN  0.06  0.15  0.40  1.01  1.60  2.60  3.33   3.85
# 2010-01-07  0.02   NaN  0.05  0.16  0.40  1.03  1.62  2.62  3.33   3.85
# 2010-01-08  0.02   NaN  0.05  0.15  0.37  0.96  1.56  2.57  3.31   3.83
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 2020-11-17  0.08  0.08  0.09  0.10  0.12  0.18  0.22  0.39  0.63   0.87
# 2020-11-18  0.07  0.09  0.09  0.10  0.11  0.16  0.22  0.40  0.64   0.88
# 2020-11-19  0.08  0.08  0.07  0.10  0.11  0.18  0.22  0.39  0.63   0.86
# 2020-11-20  0.09  0.09  0.07  0.10  0.11  0.16  0.21  0.38  0.62   0.83
# 2020-11-23  0.08  0.08  0.08  0.08  0.10  0.16  0.22  0.39  0.64   0.86
#
#             20 YR  30 YR
# Date
# 2010-01-04   4.60   4.65
# 2010-01-05   4.54   4.59
# ...

# %%
dfyc.isnull().sum()
# Out:
# 1 MO        0
# 2 MO     2200
# 3 MO        0
# 6 MO        0
# 1 YR        0
# 2 YR        0
# 3 YR        0
# 5 YR        0
# 7 YR        0
# 10 YR       0
# 20 YR       0
# 30 YR       0
# dtype: int64

# %%
dfyc.drop(columns='2 MO',inplace=True)

# %%
dfyc.dtypes
# Out:
# 1 MO     float64
# 3 MO     float64
# 6 MO     float64
# 1 YR     float64
# 2 YR     float64
# 3 YR     float64
# 5 YR     float64
# 7 YR     float64
# 10 YR    float64
# 20 YR    float64
# 30 YR    float64
# dtype: object

# %%
dfyc.loc['2010':'2015']
# Out:
#             1 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  20 YR  \
# Date
# 2010-01-04  0.05  0.08  0.18  0.45  1.09  1.66  2.65  3.36   3.85   4.60
# 2010-01-05  0.03  0.07  0.17  0.41  1.01  1.57  2.56  3.28   3.77   4.54
# 2010-01-06  0.03  0.06  0.15  0.40  1.01  1.60  2.60  3.33   3.85   4.63
# 2010-01-07  0.02  0.05  0.16  0.40  1.03  1.62  2.62  3.33   3.85   4.62
# 2010-01-08  0.02  0.05  0.15  0.37  0.96  1.56  2.57  3.31   3.83   4.61
# ...          ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 2015-12-24  0.15  0.20  0.49  0.64  1.03  1.33  1.73  2.06   2.25   2.61
# 2015-12-28  0.13  0.23  0.51  0.66  1.05  1.33  1.73  2.05   2.24   2.59
# 2015-12-29  0.18  0.23  0.50  0.67  1.09  1.38  1.81  2.12   2.32   2.69
# 2015-12-30  0.08  0.21  0.47  0.64  1.08  1.36  1.80  2.14   2.31   2.69
# 2015-12-31  0.14  0.16  0.49  0.65  1.06  1.31  1.76  2.09   2.27   2.67
#
#             30 YR
# Date
# 2010-01-04   4.65
# 2010-01-05   4.59
# 2010-01-06   4.70
# ...

# %%
dfyc['30-5Yr Spread'] = dfyc['30 YR'] - dfyc['5 YR']
dfyc['30Yr-1MO Spread'] = dfyc['30 YR'] - dfyc['1 MO']
dfyc['20-5Yr Spread'] = dfyc['20 YR'] - dfyc['5 YR']
dfyc['10-2Yr Spread'] = dfyc['10 YR'] - dfyc['2 YR']
dfyc['10-1Yr Spread'] = dfyc['10 YR'] - dfyc['1 YR']
dfyc['7-1Yr Spread'] = dfyc['7 YR'] - dfyc['1 YR']
dfyc['5-2Yr Spread'] = dfyc['5 YR'] - dfyc['2 YR']
dfyc['1-2Yr Spread'] = dfyc['5 YR'] - dfyc['1 YR']
dfyc['1Yr-1MO Spread'] = dfyc['1 YR'] - dfyc['1 MO']

# %%
dfyc = dfyc.loc['2010-08-17':'2018-08-16'].copy()

# %%
tens_twos = quandl.get("FRED/T10Y2Y", authtoken="-szaxxRjfjXjAhBgEzYR")

tens_3mo = quandl.get("FRED/T10Y3M", authtoken="-szaxxRjfjXjAhBgEzYR")

tens_twos.loc['2010':'2015']
# Out:
#             Value
# Date
# 2010-01-04   2.76
# 2010-01-05   2.76
# 2010-01-06   2.84
# 2010-01-07   2.82
# 2010-01-08   2.87
# ...           ...
# 2015-12-24   1.22
# 2015-12-28   1.19
# 2015-12-29   1.23
# 2015-12-30   1.23
# 2015-12-31   1.21
#
# [1502 rows x 1 columns]

# %%
dfyc.to_csv('../DataBank/csv_exports/yield_curve.csv')

# %%
dfyc.isnull().sum()
# Out:
# 1 MO               0
# 3 MO               0
# 6 MO               0
# 1 YR               0
# 2 YR               0
# 3 YR               0
# 5 YR               0
# 7 YR               0
# 10 YR              0
# 20 YR              0
# 30 YR              0
# 30-5Yr Spread      0
# 30Yr-1MO Spread    0
# 20-5Yr Spread      0
# 10-2Yr Spread      0
# 10-1Yr Spread      0
# 7-1Yr Spread       0
# 5-2Yr Spread       0
# 1-2Yr Spread       0
# 1Yr-1MO Spread     0
# dtype: int64
